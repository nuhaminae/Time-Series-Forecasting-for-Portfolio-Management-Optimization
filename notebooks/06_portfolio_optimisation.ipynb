# %% [markdown]
# # **Import Modules**

# %% [markdown]
# ## *python*

# %%
# Import python modules
import os
import sys

# %% [markdown]
# ## *custom*

# %%
# Import customised modules

# Define path
sys.path.append(os.path.abspath(os.path.join("..")))

# Import relevant modules
try:
    from scripts._06_portfolio_optimisation import PortfolioOptimiser

    print("Module successfully imported.")

except ImportError:
    print("Could not import module from `scripts/`.")
# Out:
# Module successfully imported.

# %% [markdown]
# # **Portfolio Optimisation**

# %%
# Load class input paths
# Specify directory
ntbk_dir = os.getcwd()  # Gets the directory of the notebook
plot_dir = os.path.join(ntbk_dir, "..", "insights", "portfolio")
processed_dir = os.path.join(ntbk_dir, "..", "data", "processed")

# %%
# Optimisation with forecasted stock prices
optimiser = PortfolioOptimiser(
    bnd_path=os.path.join(ntbk_dir, "..", "data/processed/BND_log_enriched.csv"),
    spy_path=os.path.join(ntbk_dir, "..", "data/processed/SPY_log_enriched.csv"),
    tsla_path=os.path.join(ntbk_dir, "..", "data/processed/TSLA_prediction_df.csv"),
    plot_dir=plot_dir,
    col="Predicted Return",
)
optimiser.run_pipeline()
# Out:
# 🧪 Running full optimisation pipeline...
#
# 📈 BND historical data loaded from ..\data\processed\BND_log_enriched.csv
# 🔹 BND DataFrame Head:
#         Date      Close       High        Low       Open   Volume  Trend  \
# 0 2015-07-02  60.967091  61.027232  60.937020  60.937020  1060100    NaN
# 1 2015-07-06  61.177608  61.222718  61.057331  61.222718  2210700    NaN
# 2 2015-07-07  61.237724  61.470766  61.237724  61.410630  4183200    NaN
# 3 2015-07-08  61.410606  61.463229  61.312875  61.373017  1967800    NaN
# 4 2015-07-09  61.207657  61.327940  61.177586  61.312902  1670900    NaN
#
#    Volatility  Daily Return  Log Close
# 0         NaN      0.002472   4.110334
# 1         NaN      0.003453   4.113781
# 2         NaN      0.000983   4.114763
# 3         NaN      0.002823   4.117583
# 4         NaN     -0.003305   4.114272
# 📈 SPY historical data loaded from ..\data\processed\SPY_log_enriched.csv
# 🔹 SPY DataFrame Head:
#         Date       Close        High         Low        Open     Volume  \
# 0 2015-07-02  174.756927  175.566188  174.335441  175.397596  104373700
# 1 2015-07-06  174.259628  175.043588  173.256487  173.458805  117975400
# 2 2015-07-07  175.355453  175.481894  172.059422  174.461903  173820200
# 3 2015-07-08  172.413437  174.293265  172.177405  174.006657  164020100
# 4 2015-07-09  172.725311  174.790607  172.615733  174.529275  144113100
#
#    Trend  Volatility  Daily Return  Log Close
# 0    NaN         NaN     -0.000916   5.163396
# 1    NaN         NaN     -0.002846   5.160546
# 2    NaN         NaN      0.006288   5.166815
# 3    NaN         NaN     -0.016777   5.149895
# 4    NaN         NaN      0.001809   5.151703
# 📈 TSLA historical data loaded from ..\data\processed\TSLA_prediction_df.csv
# 🔹 TSLA DataFrame Head:
#         Date  Predicted Close  Predicted Volatility  Predicted Return  \
# 0 2025-07-31        305.21716                   NaN               NaN
# 1 2025-08-01        298.58700                   NaN         -0.021723
# 2 2025-08-04        310.21410                   NaN          0.038940
# 3 2025-08-05        312.67892                   NaN          0.007946
# 4 2025-08-06        315.20508                   NaN          0.008079
#
#    Predicted Trend
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 🧪 Running full optimisation pipeline...
#
# 📊 Covariance Matrix Summary:
# Mean: 0.010051328976661398
# Max: 0.06832969011112808
# Min: -0.00184585726800722
#
# 📌 Manual Covariance Matrix:
# [[ 0.06832969 -0.00069991 -0.00119385]
#  [-0.00069991  0.00108016 -0.00184586]
#  [-0.00119385 -0.00184586  0.02853135]]
#
# 📌 PyPortfolioOpt Covariance Matrix (returns_data=True):
# [[ 0.06832969 -0.00069991 -0.00119385]
#  [-0.00069991  0.00108016 -0.00184586]
#  [-0.00119385 -0.00184586  0.02853135]]
#
# 🧪 Covariance Matrix Difference (manual vs PyPortfolioOpt): 0.000000
#
# 📈 Max Sharpe Portfolio:
# TSLA: 0.00%
# BND: 81.10%
# SPY: 18.90%
# Return: 4.33%, Volatility: 3.41%, Sharpe: 1.27
#
# 📉 Min Volatility Portfolio:
# TSLA: 2.22%
# BND: 89.16%
# SPY: 8.62%
# Return: 2.72%, Volatility: 2.81%, Sharpe: 0.97
#
# 💾 Enhanced frontier plot saved to ..\insights\portfolio\enhanced_frontier_Predicted Return.png
# 💾 Allocation pie chart saved to ..\insights\portfolio\allocation_comparison_Predicted Return.png
# ✅ Portfolio Optimisation Complete
# 🔹 Optimal Weights: OrderedDict([('TSLA', 0.0), ('BND', 0.81099), ('SPY', 0.18901)])
# 🔹 Expected Annual Return: 4.33%
# 🔹 Annual Volatility: 3.41%
# 🔹 Sharpe Ratio: 1.27

# %%
# Optimisation with historical stock prices
optimiser = PortfolioOptimiser(
    bnd_path=os.path.join(ntbk_dir, "..", "data/processed/BND_log_enriched.csv"),
    spy_path=os.path.join(ntbk_dir, "..", "data/processed/SPY_log_enriched.csv"),
    tsla_path=os.path.join(ntbk_dir, "..", "data/processed/TSLA_log_enriched.csv"),
    plot_dir=plot_dir,
    col="Daily Return",
)
optimiser.run_pipeline()
# Out:
# 🧪 Running full optimisation pipeline...
#
# 📈 BND historical data loaded from ..\data\processed\BND_log_enriched.csv
# 🔹 BND DataFrame Head:
#         Date      Close       High        Low       Open   Volume  Trend  \
# 0 2015-07-02  60.967091  61.027232  60.937020  60.937020  1060100    NaN
# 1 2015-07-06  61.177608  61.222718  61.057331  61.222718  2210700    NaN
# 2 2015-07-07  61.237724  61.470766  61.237724  61.410630  4183200    NaN
# 3 2015-07-08  61.410606  61.463229  61.312875  61.373017  1967800    NaN
# 4 2015-07-09  61.207657  61.327940  61.177586  61.312902  1670900    NaN
#
#    Volatility  Daily Return  Log Close
# 0         NaN      0.002472   4.110334
# 1         NaN      0.003453   4.113781
# 2         NaN      0.000983   4.114763
# 3         NaN      0.002823   4.117583
# 4         NaN     -0.003305   4.114272
# 📈 SPY historical data loaded from ..\data\processed\SPY_log_enriched.csv
# 🔹 SPY DataFrame Head:
#         Date       Close        High         Low        Open     Volume  \
# 0 2015-07-02  174.756927  175.566188  174.335441  175.397596  104373700
# 1 2015-07-06  174.259628  175.043588  173.256487  173.458805  117975400
# 2 2015-07-07  175.355453  175.481894  172.059422  174.461903  173820200
# 3 2015-07-08  172.413437  174.293265  172.177405  174.006657  164020100
# 4 2015-07-09  172.725311  174.790607  172.615733  174.529275  144113100
#
#    Trend  Volatility  Daily Return  Log Close
# 0    NaN         NaN     -0.000916   5.163396
# 1    NaN         NaN     -0.002846   5.160546
# 2    NaN         NaN      0.006288   5.166815
# 3    NaN         NaN     -0.016777   5.149895
# 4    NaN         NaN      0.001809   5.151703
# 📈 TSLA historical data loaded from ..\data\processed\TSLA_log_enriched.csv
# 🔹 TSLA DataFrame Head:
#         Date      Close       High        Low       Open     Volume  Trend  \
# 0 2015-07-02  18.667999  18.830000  18.220667  18.680000  107458500    NaN
# 1 2015-07-06  18.648001  18.779333  18.420000  18.591999   61828500    NaN
# 2 2015-07-07  17.858667  18.346666  17.384666  18.333332   91576500    NaN
# 3 2015-07-08  16.997334  17.386667  16.954000  17.288000   93316500    NaN
# 4 2015-07-09  17.194668  17.530001  17.119333  17.271999   50011500    NaN
#
#    Volatility  Daily Return  Log Close
# 0         NaN      0.040386   2.926811
# 1         NaN     -0.001071   2.925739
# 2         NaN     -0.042328   2.882489
# 3         NaN     -0.048231   2.833056
# 4         NaN      0.011610   2.844599
# 🧪 Running full optimisation pipeline...
#
# 📊 Covariance Matrix Summary:
# Mean: 0.05539356669393415
# Max: 0.35033057269480183
# Min: 0.0011504303335101427
#
# 📌 Manual Covariance Matrix:
# [[0.35033057 0.00186075 0.05295036]
#  [0.00186075 0.00301607 0.00115043]
#  [0.05295036 0.00115043 0.03327237]]
#
# 📌 PyPortfolioOpt Covariance Matrix (returns_data=True):
# [[0.35033057 0.00186075 0.05295036]
#  [0.00186075 0.00301607 0.00115043]
#  [0.05295036 0.00115043 0.03327237]]
#
# 🧪 Covariance Matrix Difference (manual vs PyPortfolioOpt): 0.000000
#
# 📈 Max Sharpe Portfolio:
# TSLA: 10.09%
# BND: 57.13%
# SPY: 32.78%
# Return: 10.52%, Volatility: 11.08%, Sharpe: 0.95
#
# 📉 Min Volatility Portfolio:
# TSLA: 0.00%
# BND: 94.51%
# SPY: 5.49%
# Return: 2.65%, Volatility: 5.40%, Sharpe: 0.49
#
# 💾 Enhanced frontier plot saved to ..\insights\portfolio\enhanced_frontier_Daily Return.png
# 💾 Allocation pie chart saved to ..\insights\portfolio\allocation_comparison_Daily Return.png
# ✅ Portfolio Optimisation Complete
# 🔹 Optimal Weights: OrderedDict([('TSLA', 0.10093), ('BND', 0.57127), ('SPY', 0.32781)])
# 🔹 Expected Annual Return: 10.52%
# 🔹 Annual Volatility: 11.08%
# 🔹 Sharpe Ratio: 0.95
