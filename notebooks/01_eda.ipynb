# %% [markdown]
# # **Import Modules**

# %% [markdown]
# ## *python*

# %%
# Import python modules
import os
import sys

# %% [markdown]
# ## *custom*

# %%
# Import customised modules

# Define path
sys.path.append(os.path.abspath(os.path.join("..")))

# Import relevant modules
try:
    from scripts._01_eda import EDA

    print("Module successfully imported.")

except ImportError:
    print("Could not import module from `scripts/`.")
# Out:
# Module successfully imported.

# %% [markdown]
# # **Data Analysis and Preprocessing**

# %%
# Load class input paths
# Specify directory
ntbk_dir = os.getcwd()  # Gets the directory of the notebook

raw_dir = os.path.join(ntbk_dir, "..", "data", "raw")
processed_dir = os.path.join(ntbk_dir, "..", "data", "processed")
plot_dir = os.path.join(ntbk_dir, "..", "insights", "eda")

# %% [markdown]
# ## *TSLA*

# %%
# Tesla (TSLA) Historical stock prices
processor = EDA(
    stock_name="TSLA",
    raw_dir=raw_dir,
    processed_dir=processed_dir,
    plot_dir=plot_dir,
    rolling_window=180,
)
processor.eda_processor()
# Out:
# 🧪 Running full EDA pipeline...
#
# 💾 TSLA raw data saved to ..\data\raw\TSLA_stock_price.csv.
#
# 🔹DataFrame Head:
# Price           Close       High        Low       Open     Volume
# Ticker           TSLA       TSLA       TSLA       TSLA       TSLA
# Date
# 2015-07-01  17.943333  18.174667  17.856667  18.073999   31518000
# 2015-07-02  18.667999  18.830000  18.220667  18.680000  107458500
# 2015-07-06  18.648001  18.779333  18.420000  18.591999   61828500
# 2015-07-07  17.858667  18.346666  17.384666  18.333332   91576500
# 2015-07-08  16.997334  17.386667  16.954000  17.288000   93316500
# 🔹 Shape: (2535, 5)
#
# 🔹 Columns: [('Close', 'TSLA'), ('High', 'TSLA'), ('Low', 'TSLA'), ('Open', 'TSLA'), ('Volume', 'TSLA')]
#
# 🔹 DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2535 entries, 2015-07-01 to 2025-07-30
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, TSLA)   2535 non-null   float64
#  1   (High, TSLA)    2535 non-null   float64
#  2   (Low, TSLA)     2535 non-null   float64
#  3   (Open, TSLA)    2535 non-null   float64
#  4   (Volume, TSLA)  2535 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 118.8 KB
#
# ✅ No missing values found.
#
# Describe:
# Price         Close         High          Low         Open        Volume
# Ticker         TSLA         TSLA         TSLA         TSLA          TSLA
# count   2535.000000  2535.000000  2535.000000  2535.000000  2.535000e+03
# mean     131.963002   134.960429   128.837831   132.000600  1.141789e+08
# std      120.914904   123.783736   117.996631   121.034152  7.332146e+07
# min        9.578000    10.331333     9.403333     9.488000  1.062000e+07
# 25%       18.967667    19.279667    18.575334    18.901000  6.908220e+07
# 50%       94.571335    97.666664    91.734001    94.400665  9.537450e+07
# 75%      236.761665   240.881668   232.170006   235.851669  1.322551e+08
# max      479.859985   488.540009   457.510010   475.899994  9.140820e+08
# Close — ADF p-value: 0.5732
# Close — KPSS p-value: 0.0100
# ⚠️ Series may be non-stationary. Consider differencing.
#
#
# 💾 Plot saved to ..\insights\eda\TSLA_closing_price_rolling_mean_overlay.png
# 💾 Plot saved to ..\insights\eda\TSLA_volatility_(rolling_std_dev).png
# 💾 Plot saved to ..\insights\eda\TSLA_log_return_of_close_price.png
# 💾 plot saved to ..\insights\eda\TSLA_boxplot.png
# Return — ADF p-value: 0.0000
# Return — KPSS p-value: 0.1000
# ✅ Series appears stationary.
#
# 🔍 Found 134 outlier days with |z| > 2
#
# 💾 Outlier DataFrame saved to ..\data\processed\TSLA_outliers.csv.
#
# 💾 Plot saved to ..\insights\eda\TSLA_outlier_log_return_of_close_price.png
# 📉 Value at Risk (95%): -0.0562
# 📈 Sharpe Ratio: 0.0306
#
# 🔹Processed DataFrame Head:
# Price           Close       High        Low       Open     Volume Trend  \
# Ticker           TSLA       TSLA       TSLA       TSLA       TSLA
# Date
# 2015-07-02  18.667999  18.830000  18.220667  18.680000  107458500   NaN
# 2015-07-06  18.648001  18.779333  18.420000  18.591999   61828500   NaN
# 2015-07-07  17.858667  18.346666  17.384666  18.333332   91576500   NaN
# 2015-07-08  16.997334  17.386667  16.954000  17.288000   93316500   NaN
# 2015-07-09  17.194668  17.530001  17.119333  17.271999   50011500   NaN
#
# Price      Volatility    Return
# Ticker
# Date
# 2015-07-02        NaN  0.039592
# 2015-07-06        NaN -0.001072
# 2015-07-07        NaN -0.043250
# 2015-07-08        NaN -0.049432
# 2015-07-09        NaN  0.011543
# 🔹Shape: (2534, 8)
#
# 🔹Columns: [('Close', 'TSLA'), ('High', 'TSLA'), ('Low', 'TSLA'), ('Open', 'TSLA'), ('Volume', 'TSLA'), ('Trend', ''), ('Volatility', ''), ('Return', '')]
#
# 💾 Enriched DataFrame saved to ..\data\processed\TSLA_stock_price_enriched.csv.

# %% [markdown]
# ## *BND*

# %%
# Vanguard Total Bond Market ETF (BND)
processor = EDA(
    stock_name="BND",
    raw_dir=raw_dir,
    processed_dir=processed_dir,
    plot_dir=plot_dir,
)
processor.eda_processor()
# Out:
# 🧪 Running full EDA pipeline...
#
# 💾 BND raw data saved to ..\data\raw\BND_stock_price.csv.
#
# 🔹DataFrame Head:
# Price           Close       High        Low       Open   Volume
# Ticker            BND        BND        BND        BND      BND
# Date
# 2015-07-01  60.816746  60.914471  60.764123  60.794194  5399300
# 2015-07-02  60.967079  61.027221  60.937008  60.937008  1060100
# 2015-07-06  61.177608  61.222718  61.057331  61.222718  2210700
# 2015-07-07  61.237732  61.470773  61.237732  61.410637  4183200
# 2015-07-08  61.410641  61.463263  61.312909  61.373051  1967800
# 🔹 Shape: (2535, 5)
#
# 🔹 Columns: [('Close', 'BND'), ('High', 'BND'), ('Low', 'BND'), ('Open', 'BND'), ('Volume', 'BND')]
#
# 🔹 DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2535 entries, 2015-07-01 to 2025-07-30
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   (Close, BND)   2535 non-null   float64
#  1   (High, BND)    2535 non-null   float64
#  2   (Low, BND)     2535 non-null   float64
#  3   (Open, BND)    2535 non-null   float64
#  4   (Volume, BND)  2535 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 118.8 KB
#
# ✅ No missing values found.
#
# Describe:
# Price         Close         High          Low         Open        Volume
# Ticker          BND          BND          BND          BND           BND
# count   2535.000000  2535.000000  2535.000000  2535.000000  2.535000e+03
# mean      68.469189    68.571175    68.364920    68.471392  4.434376e+06
# std        4.554601     4.563590     4.544724     4.555994  2.899511e+06
# min       60.779133    60.899416    60.764123    60.786652  0.000000e+00
# 25%       64.654358    64.731257    64.570663    64.660618  2.182050e+06
# 50%       67.604904    67.749376    67.474065    67.589066  4.121100e+06
# 75%       71.891136    72.018947    71.780700    71.886216  5.890100e+06
# max       77.318260    77.413299    77.283696    77.378741  3.396300e+07
# Close — ADF p-value: 0.5155
# Close — KPSS p-value: 0.0100
# ⚠️ Series may be non-stationary. Consider differencing.
#
#
# 💾 Plot saved to ..\insights\eda\BND_closing_price_rolling_mean_overlay.png
# 💾 Plot saved to ..\insights\eda\BND_volatility_(rolling_std_dev).png
# 💾 Plot saved to ..\insights\eda\BND_log_return_of_close_price.png
# 💾 plot saved to ..\insights\eda\BND_boxplot.png
# Return — ADF p-value: 0.0000
# Return — KPSS p-value: 0.1000
# ✅ Series appears stationary.
#
# 🔍 Found 95 outlier days with |z| > 2
#
# 💾 Outlier DataFrame saved to ..\data\processed\BND_outliers.csv.
#
# 💾 Plot saved to ..\insights\eda\BND_outlier_log_return_of_close_price.png
# 📉 Value at Risk (95%): -0.0049
# 📈 Sharpe Ratio: 0.0207
#
# 🔹Processed DataFrame Head:
# Price           Close       High        Low       Open   Volume Trend  \
# Ticker            BND        BND        BND        BND      BND
# Date
# 2015-07-02  60.967079  61.027221  60.937008  60.937008  1060100   NaN
# 2015-07-06  61.177608  61.222718  61.057331  61.222718  2210700   NaN
# 2015-07-07  61.237732  61.470773  61.237732  61.410637  4183200   NaN
# 2015-07-08  61.410641  61.463263  61.312909  61.373051  1967800   NaN
# 2015-07-09  61.207657  61.327940  61.177586  61.312902  1670900   NaN
#
# Price      Volatility    Return
# Ticker
# Date
# 2015-07-02        NaN  0.002469
# 2015-07-06        NaN  0.003447
# 2015-07-07        NaN  0.000982
# 2015-07-08        NaN  0.002820
# 2015-07-09        NaN -0.003311
# 🔹Shape: (2534, 8)
#
# 🔹Columns: [('Close', 'BND'), ('High', 'BND'), ('Low', 'BND'), ('Open', 'BND'), ('Volume', 'BND'), ('Trend', ''), ('Volatility', ''), ('Return', '')]
#
# 💾 Enriched DataFrame saved to ..\data\processed\BND_stock_price_enriched.csv.

# %% [markdown]
# ## *SPY*

# %%
# S&P 500 ETF (SPY)
processor = EDA(
    stock_name="SPY",
    raw_dir=raw_dir,
    processed_dir=processed_dir,
    plot_dir=plot_dir,
)
processor.eda_processor()
# Out:
# 🧪 Running full EDA pipeline...
#
# 💾 SPY raw data saved to ..\data\raw\SPY_stock_price.csv.
#
# 🔹DataFrame Head:
# Price            Close        High         Low        Open     Volume
# Ticker             SPY         SPY         SPY         SPY        SPY
# Date
# 2015-07-01  174.917114  175.363889  174.124717  175.110995  135979900
# 2015-07-02  174.756958  175.566219  174.335471  175.397627  104373700
# 2015-07-06  174.259598  175.043557  173.256457  173.458775  117975400
# 2015-07-07  175.355484  175.481925  172.059452  174.461933  173820200
# 2015-07-08  172.413452  174.293280  172.177420  174.006672  164020100
# 🔹 Shape: (2535, 5)
#
# 🔹 Columns: [('Close', 'SPY'), ('High', 'SPY'), ('Low', 'SPY'), ('Open', 'SPY'), ('Volume', 'SPY')]
#
# 🔹 DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2535 entries, 2015-07-01 to 2025-07-30
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   (Close, SPY)   2535 non-null   float64
#  1   (High, SPY)    2535 non-null   float64
#  2   (Low, SPY)     2535 non-null   float64
#  3   (Open, SPY)    2535 non-null   float64
#  4   (Volume, SPY)  2535 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 118.8 KB
#
# ✅ No missing values found.
#
# Describe:
# Price         Close         High          Low         Open        Volume
# Ticker          SPY          SPY          SPY          SPY           SPY
# count   2535.000000  2535.000000  2535.000000  2535.000000  2.535000e+03
# mean     334.193733   335.981619   332.114636   334.125538  8.503521e+07
# std      126.427703   127.053089   125.661286   126.391137  4.428796e+07
# min      155.869751   156.926731   153.758455   155.426500  2.027000e+07
# 25%      230.083191   234.024886   228.661756   231.007847  5.779150e+07
# 50%      305.264404   306.143457   302.033100   304.714951  7.451530e+07
# 75%      420.350510   423.114882   417.754453   420.117481  9.789180e+07
# max      637.099976   638.669983   635.539978   638.349976  5.072443e+08
# Close — ADF p-value: 0.9897
# Close — KPSS p-value: 0.0100
# ⚠️ Series may be non-stationary. Consider differencing.
#
#
# 💾 Plot saved to ..\insights\eda\SPY_closing_price_rolling_mean_overlay.png
# 💾 Plot saved to ..\insights\eda\SPY_volatility_(rolling_std_dev).png
# 💾 Plot saved to ..\insights\eda\SPY_log_return_of_close_price.png
# 💾 plot saved to ..\insights\eda\SPY_boxplot.png
# Return — ADF p-value: 0.0000
# Return — KPSS p-value: 0.1000
# ✅ Series appears stationary.
#
# 🔍 Found 118 outlier days with |z| > 2
#
# 💾 Outlier DataFrame saved to ..\data\processed\SPY_outliers.csv.
#
# 💾 Plot saved to ..\insights\eda\SPY_outlier_log_return_of_close_price.png
# 📉 Value at Risk (95%): -0.0173
# 📈 Sharpe Ratio: 0.0442
#
# 🔹Processed DataFrame Head:
# Price            Close        High         Low        Open     Volume Trend  \
# Ticker             SPY         SPY         SPY         SPY        SPY
# Date
# 2015-07-02  174.756958  175.566219  174.335471  175.397627  104373700   NaN
# 2015-07-06  174.259598  175.043557  173.256457  173.458775  117975400   NaN
# 2015-07-07  175.355484  175.481925  172.059452  174.461933  173820200   NaN
# 2015-07-08  172.413452  174.293280  172.177420  174.006672  164020100   NaN
# 2015-07-09  172.725327  174.790623  172.615749  174.529290  144113100   NaN
#
# Price      Volatility    Return
# Ticker
# Date
# 2015-07-02        NaN -0.000916
# 2015-07-06        NaN -0.002850
# 2015-07-07        NaN  0.006269
# 2015-07-08        NaN -0.016920
# 2015-07-09        NaN  0.001807
# 🔹Shape: (2534, 8)
#
# 🔹Columns: [('Close', 'SPY'), ('High', 'SPY'), ('Low', 'SPY'), ('Open', 'SPY'), ('Volume', 'SPY'), ('Trend', ''), ('Volatility', ''), ('Return', '')]
#
# 💾 Enriched DataFrame saved to ..\data\processed\SPY_stock_price_enriched.csv.
